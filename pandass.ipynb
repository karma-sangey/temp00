# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd
df = pd.read_csv("students_data_2000_rows.csv")
df.head(10)
# Out:
#    Student_ID        Name  Age  Gender Department        City  Marks  \
# 0        1001   Student_1   19    Male        ECE  Chandigarh     63
# 1        1002   Student_2   19    Male         CE    Amritsar     39
# 2        1003   Student_3   19    Male         IT      Jaipur     38
# 3        1004   Student_4   21  Female         IT    Amritsar     70
# 4        1005   Student_5   20  Female        ECE    Ludhiana     54
# 5        1006   Student_6   23    Male        CSE    Amritsar     47
# 6        1007   Student_7   23  Female        CSE    Amritsar     50
# 7        1008   Student_8   19  Female         CE    Ludhiana     59
# 8        1009   Student_9   18    Male        ECE       Delhi     64
# 9        1010  Student_10   24  Female         ME    Ludhiana     55
#
#    Attendance
# 0          68
# 1          61
# 2          95
# 3          60
# 4          73
# 5          82
# 6          84
# 7          64
# 8          66
# 9          83

# %%
df.tail(10)                          # Last 10 rows
# Out:
#       Student_ID          Name  Age  Gender Department        City  Marks  \
# 1990        2991  Student_1991   19    Male         ME       Delhi     83
# 1991        2992  Student_1992   18    Male         CE       Delhi     56
# 1992        2993  Student_1993   25    Male        CSE    Amritsar     98
# 1993        2994  Student_1994   25    Male         CE    Amritsar     86
# 1994        2995  Student_1995   22    Male         ME    Ludhiana     69
# 1995        2996  Student_1996   23  Female         CE  Chandigarh     53
# 1996        2997  Student_1997   21  Female         CE      Jaipur     67
# 1997        2998  Student_1998   25    Male        ECE  Chandigarh     56
# 1998        2999  Student_1999   25    Male        ECE    Amritsar     57
# 1999        3000  Student_2000   25    Male        CSE    Ludhiana     59
#
#       Attendance
# 1990          68
# 1991          72
# 1992          70
# 1993          60
# 1994          93
# 1995          78
# 1996          90
# 1997          93
# 1998          69
# 1999          72

# %%
df.columns
# Out:
# Index(['Student_ID', 'Name', 'Age', 'Gender', 'Department', 'City', 'Marks',
#        'Attendance'],
#       dtype='object')

# %%
df.describe()
# Out:
#         Student_ID          Age        Marks   Attendance
# count  2000.000000  2000.000000  2000.000000  2000.000000
# mean   2000.500000    21.535000    67.355000    80.185000
# std     577.494589     2.327764    18.928976    11.772811
# min    1001.000000    18.000000    35.000000    60.000000
# 25%    1500.750000    19.000000    51.000000    70.000000
# 50%    2000.500000    22.000000    67.000000    80.000000
# 75%    2500.250000    24.000000    83.250000    91.000000
# max    3000.000000    25.000000   100.000000   100.000000

# %%
df.rename(columns={"Name":"Student_Name"})
# Out:
#       Student_ID  Student_Name  Age  Gender Department        City  Marks  \
# 0           1001     Student_1   19    Male        ECE  Chandigarh     63
# 1           1002     Student_2   19    Male         CE    Amritsar     39
# 2           1003     Student_3   19    Male         IT      Jaipur     38
# 3           1004     Student_4   21  Female         IT    Amritsar     70
# 4           1005     Student_5   20  Female        ECE    Ludhiana     54
# ...          ...           ...  ...     ...        ...         ...    ...
# 1995        2996  Student_1996   23  Female         CE  Chandigarh     53
# 1996        2997  Student_1997   21  Female         CE      Jaipur     67
# 1997        2998  Student_1998   25    Male        ECE  Chandigarh     56
# 1998        2999  Student_1999   25    Male        ECE    Amritsar     57
# 1999        3000  Student_2000   25    Male        CSE    Ludhiana     59
#
#       Attendance
# 0             68
# 1             61
# 2             95
# 3             60
# 4             73
# ...          ...
# 1995          78
# 1996          90
# 1997          93
# 1998          69
# 1999          72
#
# [2000 rows x 8 columns]

# %%
df.drop("Age", axis=1)
# Out:
#       Student_ID          Name  Gender Department        City  Marks  \
# 0           1001     Student_1    Male        ECE  Chandigarh     63
# 1           1002     Student_2    Male         CE    Amritsar     39
# 2           1003     Student_3    Male         IT      Jaipur     38
# 3           1004     Student_4  Female         IT    Amritsar     70
# 4           1005     Student_5  Female        ECE    Ludhiana     54
# ...          ...           ...     ...        ...         ...    ...
# 1995        2996  Student_1996  Female         CE  Chandigarh     53
# 1996        2997  Student_1997  Female         CE      Jaipur     67
# 1997        2998  Student_1998    Male        ECE  Chandigarh     56
# 1998        2999  Student_1999    Male        ECE    Amritsar     57
# 1999        3000  Student_2000    Male        CSE    Ludhiana     59
#
#       Attendance
# 0             68
# 1             61
# 2             95
# 3             60
# 4             73
# ...          ...
# 1995          78
# 1996          90
# 1997          93
# 1998          69
# 1999          72
#
# [2000 rows x 7 columns]

# %%
df[["Name","Marks"]]
# Out:
#               Name  Marks
# 0        Student_1     63
# 1        Student_2     39
# 2        Student_3     38
# 3        Student_4     70
# 4        Student_5     54
# ...            ...    ...
# 1995  Student_1996     53
# 1996  Student_1997     67
# 1997  Student_1998     56
# 1998  Student_1999     57
# 1999  Student_2000     59
#
# [2000 rows x 2 columns]

# %%
df.sort_values(by="Marks", ascending=True)
# Out:
#       Student_ID          Name  Age  Gender Department        City  Marks  \
# 1814        2815  Student_1815   19    Male         ME    Ludhiana     35
# 914         1915   Student_915   20    Male         IT  Chandigarh     35
# 262         1263   Student_263   21    Male        ECE    Amritsar     35
# 29          1030    Student_30   18    Male         CE  Chandigarh     35
# 1063        2064  Student_1064   24    Male         CE  Chandigarh     35
# ...          ...           ...  ...     ...        ...         ...    ...
# 1942        2943  Student_1943   22    Male        CSE  Chandigarh    100
# 1570        2571  Student_1571   24    Male         ME    Amritsar    100
# 1746        2747  Student_1747   22  Female         ME    Amritsar    100
# 1781        2782  Student_1782   21  Female         ME    Amritsar    100
# 304         1305   Student_305   23  Female         IT    Ludhiana    100
#
#       Attendance
# 1814          87
# 914           99
# 262           99
# 29            64
# 1063          86
# ...          ...
# 1942          70
# 1570          94
# 1746          85
# 1781          72
# 304           95
#
# [2000 rows x 8 columns]

# %%
df.sample(10)
# Out:
#       Student_ID          Name  Age  Gender Department        City  Marks  \
# 1077        2078  Student_1078   24  Female        CSE       Delhi     82
# 190         1191   Student_191   20  Female         IT       Delhi     38
# 751         1752   Student_752   22  Female         ME  Chandigarh     50
# 835         1836   Student_836   22  Female         ME       Delhi     99
# 388         1389   Student_389   21  Female         CE    Ludhiana     67
# 1231        2232  Student_1232   18    Male         ME       Delhi     66
# 150         1151   Student_151   22    Male        ECE    Ludhiana     97
# 1115        2116  Student_1116   18  Female         IT      Jaipur     42
# 1014        2015  Student_1015   23    Male        ECE    Ludhiana     57
# 804         1805   Student_805   25    Male        CSE    Amritsar     74
#
#       Attendance
# 1077          82
# 190           68
# 751           74
# 835           84
# 388           91
# 1231          91
# 150           69
# 1115          69
# 1014          88
# 804           83
